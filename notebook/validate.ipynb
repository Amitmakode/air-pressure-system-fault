# %%
import numpy as np 
from scipy import stats
rng = np.random.default_rng()
sample1 = stats.uniform.rvs(size=100, random_state=rng)
sample2 = stats.norm.rvs(size=110, random_state=rng)
respons = stats.ks_2samp(sample1,sample2)

# %%
sample1
# Out:
# array([0.25631348, 0.46935828, 0.00714925, 0.00538482, 0.05268439,
#        0.09003055, 0.71991393, 0.35631832, 0.91676235, 0.84429898,
#        0.20893246, 0.33192971, 0.52115219, 0.73666904, 0.57851786,
#        0.20272114, 0.97604303, 0.31081324, 0.18451265, 0.89966482,
#        0.97237652, 0.81734779, 0.38965442, 0.13039587, 0.25090326,
#        0.80479025, 0.45466186, 0.38880816, 0.69954851, 0.51934719,
#        0.6452739 , 0.58700324, 0.64632112, 0.93342352, 0.47057449,
#        0.12888825, 0.45377852, 0.05400321, 0.04653248, 0.87802148,
#        0.46007913, 0.89652183, 0.74069765, 0.88030817, 0.05263647,
#        0.64330642, 0.17345488, 0.68136578, 0.00617917, 0.3046177 ,
#        0.62018299, 0.42449149, 0.95103273, 0.11872545, 0.57746626,
#        0.77759317, 0.84889403, 0.62113778, 0.46501462, 0.46908643,
#        0.21989499, 0.21020065, 0.48298574, 0.99161745, 0.39383637,
#        0.4229079 , 0.98766385, 0.18623623, 0.65121665, 0.95417444,
#        0.22908803, 0.61733925, 0.68484035, 0.10473813, 0.45549035,
#        0.64674466, 0.48900095, 0.52465531, 0.77556517, 0.32584608,
#        0.22824175, 0.80112298, 0.45023318, 0.67361252, 0.95821725,
#        0.69095625, 0.76742601, 0.04297215, 0.84055502, 0.9110839 ,
#        0.40901502, 0.01357953, 0.85385527, 0.96130497, 0.42127154,
#        0.18111511, 0.64794062, 0.79543406, 0.96521175, 0.73014446])

# %%
sample2
# Out:
# array([ 0.5225197 ,  0.18874294, -1.14912191, -0.45483561,  2.2130306 ,
#         0.824573  ,  0.13690402, -1.28472917,  0.8207543 , -1.04581892,
#        -0.71334454, -1.57841157, -1.17107626,  0.57796742,  0.91804317,
#        -0.82781177,  0.22746037,  0.21963943,  0.60963952,  0.04669284,
#         1.50768833, -0.34447543,  0.05736146,  1.85583851,  0.33428508,
#        -0.23183575, -0.42250244, -0.37967432,  0.49132606, -1.22498927,
#        -0.62591136, -1.18498378,  1.89722585,  0.89823668, -1.30974442,
#        -1.22514145, -1.2557298 , -0.15628753, -0.01385015,  1.94481115,
#         0.46250068,  0.32487412,  0.74030599, -0.31157567, -1.97181605,
#         0.32791061,  0.25715524, -0.09786995,  1.01893818, -0.59344316,
#        -0.73143251, -0.34464257,  0.33792889,  0.05355492, -0.25452879,
#        -0.33579522,  0.17609549, -2.40739678, -0.20089425, -0.14939709,
#         1.10109924,  0.80880629,  0.36800171,  0.58985636,  0.1306973 ,
#        -0.07679631,  0.30582649, -0.57122892, -0.22142309,  0.23559459,
#         0.26074526,  1.49059421, -0.79074252,  0.89218733, -1.03721929,
#         0.29790048, -0.1482317 ,  0.32538505,  0.60548786, -0.57420111,
#        -1.55350899, -0.32059774, -0.66019036, -0.29771286, -0.10856957,
#        -0.9322474 , -1.21427938,  1.42582901,  0.00654382, -1.38293477,
#         0.34451709,  0.51501307,  0.23147052, -0.96784489,  0.74436   ,
#         0.52839461,  0.2337295 ,  0.53935306, -1.74963991,  0.46019611,
#         0.51281719,  0.29132051, -0.14693674, -1.70302067, -1.47909026,
#         0.16751769, -0.31423233,  0.0604694 , -1.64301875,  0.23204342])

# %%
respons
# Out:
# KstestResult(statistic=0.4818181818181818, pvalue=1.4622516077174367e-11)

# %%
round(respons.pvalue)
# Out:
# 0

# %%
#Anomly in my dataset

##1.High null value
##2.Missing values
##3.Outliers
##4.Categorical:
#### Gender ---> MALE, FEMALE,

# %%
from glob import glob

# %%
glob("/config/workspace/saved_models/1**/*.pkl")
# Out:
# ['/config/workspace/saved_models/1/model.pkl']
